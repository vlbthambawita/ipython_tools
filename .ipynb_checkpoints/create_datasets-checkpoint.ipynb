# %% [markdown]
# # create datasets

# %%
import os
import shutil
from tqdm import tqdm_notebook
import random
from PIL import Image
import numpy as np

# %%
src_dir = "/home/vajira/DL/common_datasets/sperm_train_and_test_frames/sperm_frames/train"

# %%
dst_dir = "/home/vajira/DL/common_datasets/sperm_and_cityscape/train/A"

# %%
250* 53
# Out:
# 13250

# %%
f_i = 0;
for f in tqdm_notebook(os.listdir(src_dir)):
    folder = os.path.join(src_dir, f)
    #print(folder)
    for i in tqdm_notebook(os.listdir(folder)):
        full_file_path = os.path.join(folder, i)
        #print(full_file_path)
        shutil.copyfile(full_file_path, os.path.join(dst_dir, str(f_i) +"_" + i))
    f_i += 1

# %%
l = [1,2,3]

# %%
l[2]
# Out:
# 3

# %%
src_all_img_dir = "/home/vajira/DL/common_datasets/sperm_train_and_test_frames/sperm_frames/train_all_frames"

# %%
dst_dir = "/home/vajira/DL/common_datasets/sperm_and_cityscape/train/A"

# %%
random_img_list = random.sample(range(1, 13250), 2975) # 2975 = number of segmented images available

# %%
len(random_img_list)
# Out:
# 2975

# %%
all_imgs = os.listdir(src_all_img)

# %%
len(all_imgs)
# Out:
# 13250

# %%
for i in range(2975):
    selected_img =all_imgs[random_img_list[i]]
    shutil.copyfile(os.path.join(src_all_img_dir,selected_img), os.path.join(dst_dir, selected_img))

# %% [markdown]
# # Copying all test folder frames to one folder

# %%
src_dir = "/home/vajira/DL/common_datasets/sperm_train_and_test_frames/sperm_frames/test"

# %%
dst_dir = "/home/vajira/DL/common_datasets/sperm_train_and_test_frames/sperm_frames/test_all_frames"

# %%
26*250
# Out:
# 6500

# %%
f_i = 0;
for f in tqdm_notebook(os.listdir(src_dir)):
    folder = os.path.join(src_dir, f)
    #print(folder)
    for i in tqdm_notebook(os.listdir(folder)):
        full_file_path = os.path.join(folder, i)
        #print(full_file_path)
        shutil.copyfile(full_file_path, os.path.join(dst_dir, str(f_i) +"_" + i))
    f_i += 1

# %% [markdown]
# # Making sperm 4k 1k dataset

# %%
src_all_img_dir = "/home/vajira/DL/common_datasets/sperm_train_and_test_frames/sperm_frames/train_all_frames"

# %%
dst_train_dir = "/home/vajira/DL/common_datasets/sperm_4k_1k/train"

# %%
dst_test_dir = "/home/vajira/DL/common_datasets/sperm_4k_1k/test"

# %%
random_img_numbers = random.sample(range(1, 13250), 4000) # 2975 = number of segmented images available

# %%
all_imgs = os.listdir(src_all_img_dir)

# %%
len(all_imgs)
# Out:
# 13250

# %%
for i in tqdm_notebook(range(3000)):
    selected_img =all_imgs[random_img_numbers[i]]
    shutil.copyfile(os.path.join(src_all_img_dir,selected_img), os.path.join(dst_train_dir, selected_img))
for i in tqdm_notebook(range(3000, len(random_img_numbers))):
    selected_img =all_imgs[random_img_numbers[i]]
    shutil.copyfile(os.path.join(src_all_img_dir,selected_img), os.path.join(dst_test_dir, selected_img))

# %% [markdown]
# # Making real test set

# %%
src_all_img_dir = "/home/vajira/DL/common_datasets/sperm_train_and_test_frames/sperm_frames/test_all_frames"

# %%
dst_test_dir = "/home/vajira/DL/common_datasets/sperm_4k_1k/real_test_set/a"

# %%
random_img_numbers = random.sample(range(1, 6500), 1000)

# %%
all_imgs = os.listdir(src_all_img_dir)

# %%
len(all_imgs)
# Out:
# 6500

# %%
for i in tqdm_notebook(range(1000)):
    selected_img =all_imgs[random_img_numbers[i]]
    shutil.copyfile(os.path.join(src_all_img_dir,selected_img), os.path.join(dst_test_dir, selected_img))

# %% [markdown]
# # Generating sample images from test set - by resizing - 256 -> 64 -> 256

# %%
src_all_img_dir = "/home/vajira/DL/common_datasets/sperm_4k_1k/real_test_set/b"

# %%
dst_test_dir = "/home/vajira/DL/common_datasets/sperm_4k_1k/rescaled_256_64_256"

# %%
all_imgs = os.listdir(src_all_img_dir)

# %%
len(all_imgs)
# Out:
# 1000

# %%
random_img_numbers = random.sample(range(1, 1000), 200)

# %%
for i in tqdm_notebook(range(200)):
    selected_img =all_imgs[random_img_numbers[i]]
    img = Image.open(os.path.join(src_all_img_dir, selected_img))
    img_64 = img.resize((64, 64))
    img_256 = img_64.resize((256, 256))
    img_256.save(os.path.join(dst_test_dir, selected_img), "PNG")
    # shutil.copyfile(os.path.join(src_all_img_dir,selected_img), os.path.join(dst_test_dir, selected_img))

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=256x256 at 0x7FDC2ABF1978>

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=256x256 at 0x7FDC2B7F4908>

# %%
img_64
# Out:
# <PIL.Image.Image image mode=RGBA size=64x64 at 0x7FDC2B7E6B00>

# %%
img_256
# Out:
# <PIL.Image.Image image mode=RGBA size=256x256 at 0x7FDC2B7D3DD8>

# %%
np_img =np.array(img)
np_img.shape
# Out:
# (256, 256, 4)

# %%
np_img_256 = np.array(img_256)
np_img_256.shape
# Out:
# (256, 256, 4)

# %% [markdown]
# # Generating training samples for super resolution gan (256 --> 64)

# %%
src_all_img_dir = "/home/vajira/DL/common_datasets/sperm_4k_1k/train/b" # Training hog images 256 (High resolution)
dst_test_dir = "/home/vajira/DL/common_datasets/sperm_4k_1k/train/hog_64" # Rescaled 64 images (Low resolution)

# %%
all_imgs = os.listdir(src_all_img_dir)

# %%
len(all_imgs)
# Out:
# 3000

# %%
for i in tqdm_notebook(all_imgs):
    selected_img = i
    img = Image.open(os.path.join(src_all_img_dir, selected_img))
    img_64 = img.resize((64, 64))
    img_64.save(os.path.join(dst_test_dir, selected_img), "PNG")
